# %% [markdown]
# # Reading In Files - Pandas

# %%
import pandas as pd

# %%
df = pd.read_csv("/Users/shayan_saleem/Desktop/Example/Companies.csv")
df
# Out:
#     Rank                      Name                    Industry  \
# 0      1                   Walmart                      Retail
# 1      2                    Amazon  Retail and cloud computing
# 2      3                ExxonMobil          Petroleum industry
# 3      4                     Apple        Electronics industry
# 4      5        UnitedHealth Group                  Healthcare
# ..   ...                       ...                         ...
# 95    96                  Best Buy                      Retail
# 96    97      Bristol-Myers Squibb     Pharmaceutical industry
# 97    98           United Airlines                     Airline
# 98    99  Thermo Fisher Scientific      Laboratory instruments
# 99   100                  Qualcomm                  Technology
#
#    Revenue (USD millions) Revenue growth  Employees             Headquarters
# 0                 611,289           6.7%  2,100,000    Bentonville, Arkansas
# ...

# %%
df = pd.read_csv("/Users/shayan_saleem/Desktop/Example/Companies.txt")
df
# Out:
#     Rank                      Name                    Industry  \
# 0      1                   Walmart                      Retail
# 1      2                    Amazon  Retail and cloud computing
# 2      3                ExxonMobil          Petroleum industry
# 3      4                     Apple        Electronics industry
# 4      5        UnitedHealth Group                  Healthcare
# ..   ...                       ...                         ...
# 95    96                  Best Buy                      Retail
# 96    97      Bristol-Myers Squibb     Pharmaceutical industry
# 97    98           United Airlines                     Airline
# 98    99  Thermo Fisher Scientific      Laboratory instruments
# 99   100                  Qualcomm                  Technology
#
#    Revenue (USD millions) Revenue growth  Employees             Headquarters
# 0                 611,289           6.7%  2,100,000    Bentonville, Arkansas
# ...

# %%
df2 = pd.read_excel("/Users/shayan_saleem/Downloads/CovidDeaths.xlsx")
df2
# Out:
#       iso_code continent     location       date  population  total_cases  \
# 0          AFG      Asia  Afghanistan 2020-02-24  38928341.0          1.0
# 1          AFG      Asia  Afghanistan 2020-02-25  38928341.0          1.0
# 2          AFG      Asia  Afghanistan 2020-02-26  38928341.0          1.0
# 3          AFG      Asia  Afghanistan 2020-02-27  38928341.0          1.0
# 4          AFG      Asia  Afghanistan 2020-02-28  38928341.0          1.0
# ...        ...       ...          ...        ...         ...          ...
# 85166      ZWE    Africa     Zimbabwe 2021-04-26  14862927.0      38102.0
# 85167      ZWE    Africa     Zimbabwe 2021-04-27  14862927.0      38164.0
# 85168      ZWE    Africa     Zimbabwe 2021-04-28  14862927.0      38191.0
# 85169      ZWE    Africa     Zimbabwe 2021-04-29  14862927.0      38235.0
# 85170      ZWE    Africa     Zimbabwe 2021-04-30  14862927.0      38257.0
#
#        new_cases  new_cases_smoothed  total_deaths  new_deaths  ...  \
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85171 entries, 0 to 85170
# Data columns (total 26 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   iso_code                            85171 non-null  object
#  1   continent                           81060 non-null  object
#  2   location                            85171 non-null  object
#  3   date                                85171 non-null  datetime64[ns]
#  4   population                          84622 non-null  float64
#  5   total_cases                         83072 non-null  float64
#  6   new_cases                           83070 non-null  float64
#  7   new_cases_smoothed                  82069 non-null  float64
#  8   total_deaths                        73408 non-null  float64
#  9   new_deaths                          73566 non-null  float64
#  10  new_deaths_smoothed                 82069 non-null  float64
# ...

# %%
df2.head(10)
# Out:
#   iso_code continent     location       date  population  total_cases  \
# 0      AFG      Asia  Afghanistan 2020-02-24  38928341.0          1.0
# 1      AFG      Asia  Afghanistan 2020-02-25  38928341.0          1.0
# 2      AFG      Asia  Afghanistan 2020-02-26  38928341.0          1.0
# 3      AFG      Asia  Afghanistan 2020-02-27  38928341.0          1.0
# 4      AFG      Asia  Afghanistan 2020-02-28  38928341.0          1.0
# 5      AFG      Asia  Afghanistan 2020-02-29  38928341.0          1.0
# 6      AFG      Asia  Afghanistan 2020-03-01  38928341.0          1.0
# 7      AFG      Asia  Afghanistan 2020-03-02  38928341.0          1.0
# 8      AFG      Asia  Afghanistan 2020-03-03  38928341.0          2.0
# 9      AFG      Asia  Afghanistan 2020-03-04  38928341.0          4.0
#
#    new_cases  new_cases_smoothed  total_deaths  new_deaths  ...  \
# 0        1.0                 NaN           NaN         NaN  ...
# 1        0.0                 NaN           NaN         NaN  ...
# ...

# %%
df2.tail(10)
# Out:
#       iso_code continent  location       date  population  total_cases  \
# 85161      ZWE    Africa  Zimbabwe 2021-04-21  14862927.0      37980.0
# 85162      ZWE    Africa  Zimbabwe 2021-04-22  14862927.0      38018.0
# 85163      ZWE    Africa  Zimbabwe 2021-04-23  14862927.0      38045.0
# 85164      ZWE    Africa  Zimbabwe 2021-04-24  14862927.0      38064.0
# 85165      ZWE    Africa  Zimbabwe 2021-04-25  14862927.0      38086.0
# 85166      ZWE    Africa  Zimbabwe 2021-04-26  14862927.0      38102.0
# 85167      ZWE    Africa  Zimbabwe 2021-04-27  14862927.0      38164.0
# 85168      ZWE    Africa  Zimbabwe 2021-04-28  14862927.0      38191.0
# 85169      ZWE    Africa  Zimbabwe 2021-04-29  14862927.0      38235.0
# 85170      ZWE    Africa  Zimbabwe 2021-04-30  14862927.0      38257.0
#
#        new_cases  new_cases_smoothed  total_deaths  new_deaths  ...  \
# 85161      105.0              87.286        1555.0         1.0  ...
# ...

# %%
df2['continent']
# Out:
# 0          Asia
# 1          Asia
# 2          Asia
# 3          Asia
# 4          Asia
#           ...
# 85166    Africa
# 85167    Africa
# 85168    Africa
# 85169    Africa
# 85170    Africa
# Name: continent, Length: 85171, dtype: object

# %%
#Location = loc
df2.loc[224]
# Out:
# iso_code                                              AFG
# continent                                            Asia
# location                                      Afghanistan
# date                                  2020-10-05 00:00:00
# population                                     38928341.0
# total_cases                                       39422.0
# new_cases                                            81.0
# new_cases_smoothed                                 26.143
# total_deaths                                       1468.0
# new_deaths                                            4.0
# new_deaths_smoothed                                 1.429
# total_cases_per_million                          1012.681
# new_cases_per_million                               2.081
# new_cases_smoothed_per_million                      0.672
# total_deaths_per_million                            37.71
# new_deaths_per_million                              0.103
# ...

# %%
#integer indexing location
df2.iloc[224]
# Out:
# iso_code                                              AFG
# continent                                            Asia
# location                                      Afghanistan
# date                                  2020-10-05 00:00:00
# population                                     38928341.0
# total_cases                                       39422.0
# new_cases                                            81.0
# new_cases_smoothed                                 26.143
# total_deaths                                       1468.0
# new_deaths                                            4.0
# new_deaths_smoothed                                 1.429
# total_cases_per_million                          1012.681
# new_cases_per_million                               2.081
# new_cases_smoothed_per_million                      0.672
# total_deaths_per_million                            37.71
# new_deaths_per_million                              0.103
# ...

# %%
df
# Out:
#     Rank                      Name                    Industry  \
# 0      1                   Walmart                      Retail
# 1      2                    Amazon  Retail and cloud computing
# 2      3                ExxonMobil          Petroleum industry
# 3      4                     Apple        Electronics industry
# 4      5        UnitedHealth Group                  Healthcare
# ..   ...                       ...                         ...
# 95    96                  Best Buy                      Retail
# 96    97      Bristol-Myers Squibb     Pharmaceutical industry
# 97    98           United Airlines                     Airline
# 98    99  Thermo Fisher Scientific      Laboratory instruments
# 99   100                  Qualcomm                  Technology
#
#    Revenue (USD millions) Revenue growth  Employees             Headquarters
# 0                 611,289           6.7%  2,100,000    Bentonville, Arkansas
# ...

# %%
df[df['Rank'] <= 10]
# Out:
#    Rank                  Name                        Industry  \
# 0     1               Walmart                          Retail
# 1     2                Amazon      Retail and cloud computing
# 2     3            ExxonMobil              Petroleum industry
# 3     4                 Apple            Electronics industry
# 4     5    UnitedHealth Group                      Healthcare
# 5     6            CVS Health                      Healthcare
# 6     7    Berkshire Hathaway                    Conglomerate
# 7     8              Alphabet  Technology and cloud computing
# 8     9  McKesson Corporation                          Health
# 9    10   Chevron Corporation              Petroleum industry
#
#   Revenue (USD millions) Revenue growth  Employees               Headquarters
# 0                611,289           6.7%  2,100,000      Bentonville, Arkansas
# 1                513,983           9.4%  1,540,000        Seattle, Washington
# ...

# %%
specific_company = ['Walmart','CVS Health']
df[df['Name'].isin(specific_company)]
# Out:
#    Rank        Name    Industry Revenue (USD millions) Revenue growth  \
# 0     1     Walmart      Retail                611,289           6.7%
# 5     6  CVS Health  Healthcare                322,467          10.4%
#
#    Employees              Headquarters
# 0  2,100,000     Bentonville, Arkansas
# 5    259,500  Woonsocket, Rhode Island

# %%
df[df['Name'].str.contains('Apple')]
# Out:
#    Rank   Name              Industry Revenue (USD millions) Revenue growth  \
# 3     4  Apple  Electronics industry                394,328           7.8%
#
#   Employees           Headquarters
# 3   164,000  Cupertino, California

# %%
df2 = df.set_index()

# %%
df
# Out:
#     Rank                      Name                    Industry  \
# 0      1                   Walmart                      Retail
# 1      2                    Amazon  Retail and cloud computing
# 2      3                ExxonMobil          Petroleum industry
# 3      4                     Apple        Electronics industry
# 4      5        UnitedHealth Group                  Healthcare
# ..   ...                       ...                         ...
# 95    96                  Best Buy                      Retail
# 96    97      Bristol-Myers Squibb     Pharmaceutical industry
# 97    98           United Airlines                     Airline
# 98    99  Thermo Fisher Scientific      Laboratory instruments
# 99   100                  Qualcomm                  Technology
#
#    Revenue (USD millions) Revenue growth  Employees             Headquarters
# 0                 611,289           6.7%  2,100,000    Bentonville, Arkansas
# ...

# %%
#order by
df[df['Rank'] < 10].sort_values(by=['Rank','Headquarters'], ascending=[False,True])
# Out:
#    Rank                  Name                        Industry  \
# 8     9  McKesson Corporation                          Health
# 7     8              Alphabet  Technology and cloud computing
# 6     7    Berkshire Hathaway                    Conglomerate
# 5     6            CVS Health                      Healthcare
# 4     5    UnitedHealth Group                      Healthcare
# 3     4                 Apple            Electronics industry
# 2     3            ExxonMobil              Petroleum industry
# 1     2                Amazon      Retail and cloud computing
# 0     1               Walmart                          Retail
#
#   Revenue (USD millions) Revenue growth  Employees               Headquarters
# 8                276,711           4.8%     48,500              Irving, Texas
# 7                282,836           9.8%    156,000  Mountain View, California
# 6                302,089           9.4%    383,000            Omaha, Nebraska
# ...

# %%
#Group by
group_by_frame = df.groupby('Industry')

# %%
group_by_frame.mean()

# %%
group_by_frame.count()
# Out:
#                                     Rank  Name  Revenue (USD millions)  \
# Industry
# Aerospace and defense                  2     2                       2
# Agriculture cooperative                1     1                       1
# Agriculture manufacturing              1     1                       1
# Airline                                3     3                       3
# Apparel                                1     1                       1
# Automotive and energy                  1     1                       1
# Automotive industry                    2     2                       2
# Beverage                               1     1                       1
# Chemical industry                      1     1                       1
# Conglomerate                           3     3                       3
# Conglomerate and telecomunications     1     1                       1
# Consumer products manufacturing        1     1                       1
# ...

# %%
group_by_frame.min()
# Out:
#                                     Rank                          Name  \
# Industry
# Aerospace and defense                 60                        Boeing
# Agriculture cooperative               92                           CHS
# Agriculture manufacturing             83                    John Deere
# Airline                               87             American Airlines
# Apparel                               95                          Nike
# Automotive and energy                 50                         Tesla
# Automotive industry                   19            Ford Motor Company
# Beverage                              46                       PepsiCo
# Chemical industry                     77          Dow Chemical Company
# Conglomerate                           7            Berkshire Hathaway
# Conglomerate and telecomunications    30                          AT&T
# Consumer products manufacturing       51              Procter & Gamble
# ...

# %%
group_by_frame.max()
# Out:
#                                     Rank                                 Name  \
# Industry
# Aerospace and defense                 62                      Lockheed Martin
# Agriculture cooperative               92                                  CHS
# Agriculture manufacturing             83                           John Deere
# Airline                               98                      United Airlines
# Apparel                               95                                 Nike
# Automotive and energy                 50                                Tesla
# Automotive industry                   21                       General Motors
# Beverage                              46                              PepsiCo
# Chemical industry                     77                 Dow Chemical Company
# Conglomerate                          59                      RTX Corporation
# Conglomerate and telecomunications    30                                 AT&T
# ...

# %%
df.groupby('Industry').agg({'Revenue growth': ['max', 'count', 'sum']})
# Out:
#                                    Revenue growth        \
#                                               max count
# Industry
# Aerospace and defense                        6.9%     2
# Agriculture cooperative                     24.3%     1
# Agriculture manufacturing                   19.4%     1
# Airline                                     82.5%     3
# Apparel                                      4.9%     1
# Automotive and energy                       51.4%     1
# Automotive industry                         23.4%     2
# Beverage                                     8.7%     1
# Chemical industry                            3.5%     1
# Conglomerate                                 9.4%     3
# Conglomerate and telecomunications          28.5%     1
# Consumer products manufacturing              5.3%     1
# Electronics industry                         7.8%     1
# Financial                                    8.6%     2
# Financial services                          21.7%     1
# ...
